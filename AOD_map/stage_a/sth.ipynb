# %%
import pandas as pd
import io

post_data = """
    site season             product   N     R     R2  RMSE   MAE   Bias  pct_EE
Bac_Lieu    ALL     AOD_himawari_l2 141 0.263 -0.100 0.164 0.129 -0.029  46.099
Bac_Lieu    ALL     AOD_himawari_l3  20 0.771 -0.578 0.172 0.146 -0.146  40.000
Bac_Lieu    ALL     AOD_modis_maiac 218 0.547  0.275 0.144 0.109  0.009  54.128
Bac_Lieu    ALL    AOD_viirs_noaa20  53 0.628  0.369 0.133 0.095  0.021  62.264
Bac_Lieu    ALL      AOD_viirs_snpp  56 0.782  0.578 0.075 0.057 -0.012  76.786
Bac_Lieu    ALL B2_equal_weight_pre 402 0.546 -0.047 0.171 0.120  0.058  54.726
Bac_Lieu    ALL              merged 404 0.531  0.263 0.144 0.107 -0.004  56.188
Bac_Lieu    dry     AOD_himawari_l2 135 0.271 -0.111 0.165 0.129 -0.035  46.667
Bac_Lieu    dry     AOD_himawari_l3  20 0.771 -0.578 0.172 0.146 -0.146  40.000
Bac_Lieu    dry     AOD_modis_maiac 149 0.660  0.389 0.144 0.102 -0.039  63.087
Bac_Lieu    dry    AOD_viirs_noaa20  49 0.696  0.479 0.125 0.090  0.011  63.265
Bac_Lieu    dry      AOD_viirs_snpp  50 0.759  0.542 0.078 0.061 -0.011  74.000
Bac_Lieu    dry B2_equal_weight_pre 321 0.537 -0.041 0.178 0.120  0.044  59.190
Bac_Lieu    dry              merged 323 0.596  0.318 0.143 0.103 -0.032  60.372
Bac_Lieu    wet     AOD_himawari_l2   6   NaN    NaN   NaN   NaN    NaN     NaN
Bac_Lieu    wet     AOD_modis_maiac  69 0.348 -3.961 0.144 0.125  0.114  34.783
Bac_Lieu    wet    AOD_viirs_noaa20   4   NaN    NaN   NaN   NaN    NaN     NaN
Bac_Lieu    wet      AOD_viirs_snpp   6   NaN    NaN   NaN   NaN    NaN     NaN
Bac_Lieu    wet B2_equal_weight_pre  81 0.373 -4.395 0.145 0.123  0.113  37.037
Bac_Lieu    wet              merged  81 0.342 -4.341 0.144 0.122  0.108  39.506
NGHIA_DO    ALL     AOD_himawari_l2 418 0.870  0.742 0.316 0.240  0.067  45.215
NGHIA_DO    ALL     AOD_himawari_l3 156 0.889  0.705 0.299 0.236  0.125  41.667
NGHIA_DO    ALL     AOD_modis_maiac 220 0.933  0.806 0.313 0.257  0.102  24.545
NGHIA_DO    ALL    AOD_viirs_noaa20 100 0.961  0.922 0.176 0.114 -0.016  72.000
NGHIA_DO    ALL      AOD_viirs_snpp  94 0.966  0.931 0.166 0.111 -0.004  72.340
NGHIA_DO    ALL B2_equal_weight_pre 608 0.883  0.715 0.353 0.228 -0.152  52.796
NGHIA_DO    ALL              merged 614 0.905  0.809 0.289 0.219  0.069  43.322
NGHIA_DO    dry     AOD_himawari_l2 387 0.872  0.743 0.322 0.246  0.078  45.220
NGHIA_DO    dry     AOD_himawari_l3 156 0.889  0.705 0.299 0.236  0.125  41.667
NGHIA_DO    dry     AOD_modis_maiac 178 0.935  0.814 0.324 0.260  0.082  26.966
NGHIA_DO    dry    AOD_viirs_noaa20  94 0.960  0.921 0.179 0.114 -0.009  75.532
NGHIA_DO    dry      AOD_viirs_snpp  82 0.963  0.926 0.176 0.119 -0.001  70.732
NGHIA_DO    dry B2_equal_weight_pre 528 0.882  0.708 0.370 0.242 -0.165  52.841
viirs_noaa20 Bac_Lieu ALL 59 0.599 -0.289 0.185 0.108 45.763 0.633 0.209
viirs_noaa20 Bac_Lieu dry 55 0.614 -0.190 0.183 0.106 45.455 0.630 0.208
viirs_noaa20 Bac_Lieu wet 4 NaN NaN NaN NaN NaN NaN NaN
viirs_noaa20 NGHIA_DO ALL 102 0.946 0.742 0.327 0.114 58.824 1.222 -0.057
viirs_noaa20 NGHIA_DO dry 96 0.943 0.733 0.336 0.129 61.458 1.212 -0.042
viirs_noaa20 NGHIA_DO wet 6 NaN NaN NaN NaN NaN NaN NaN
viirs_snpp ALL ALL 155 0.951 0.707 0.317 0.128 58.065 1.271 -0.018
viirs_snpp ALL dry 137 0.949 0.694 0.336 0.144 56.934 1.268 -0.014
viirs_snpp ALL wet 18 0.447 -0.555 0.086 0.007 66.667 0.586 0.083
viirs_snpp Bac_Lieu ALL 59 0.791 -0.397 0.136 0.104 49.153 0.993 0.105
viirs_snpp Bac_Lieu dry 53 0.772 -0.491 0.141 0.108 47.170 0.947 0.121
viirs_snpp Bac_Lieu wet 6 NaN NaN NaN NaN NaN NaN NaN
viirs_snpp NGHIA_DO ALL 96 0.949 0.664 0.389 0.143 63.542 1.317 -0.089
viirs_snpp NGHIA_DO dry 84 0.946 0.633 0.414 0.167 63.095 1.318 -0.091
viirs_snpp NGHIA_DO wet 12 0.400 -1.087 0.085 -0.021 66.667 0.583 0.066"""

df_post = pd.read_csv(io.StringIO(post_data), sep='\s+')
df_pre = pd.read_csv(io.StringIO(pre_data), sep='\s+')

# Standardize names
df_post['sensor'] = df_post['product'].str.replace('AOD_', '', regex=False)

# Merge on sensor, site, season
merged = pd.merge(
    df_post[['sensor', 'site', 'season', 'RMSE', 'Bias']].rename(
        columns={
            'RMSE': 'post_rmse',
            'Bias': 'post_bias',
            'pct_EE': 'post_pct_EE'
        }
    ),
    df_pre[['sensor', 'site', 'season', 'RMSE', 'MBE']].rename(
        columns={
            'RMSE': 'pre_rmse',
            'MBE': 'pre_bias',
            # 'pct_EE': 'pre_pct_EE'
        }
    ),
    on=['sensor', 'site', 'season'],
    how='inner'
)

merged['ΔRMSE (Post - Pre)'] = merged['post_rmse'] - merged['pre_rmse']
merged['Δ|Bias| (Post - Pre)'] = abs(merged['post_bias']) - abs(merged['pre_bias'])
# merged['Δpct_EE (Post - Pre)'] = merged['post_pct_EE'] - merged['pre_pct_EE']

# Save to CSV
# merged.to_csv('bias_comparison.csv', index=False)
# print(merged.to_markdown(index=False))
print(merged.to_string(index=False))
# Out:
#       sensor     site season  post_rmse  post_bias  pre_rmse  pre_bias  ΔRMSE (Post - Pre)  Δ|Bias| (Post - Pre)
#  himawari_l2 Bac_Lieu    ALL      0.164     -0.029     0.265     0.121              -0.101                -0.092
#  himawari_l3 Bac_Lieu    ALL      0.172     -0.146     0.087     0.019               0.085                 0.127
#  modis_maiac Bac_Lieu    ALL      0.144      0.009     0.143     0.009               0.001                 0.000
# viirs_noaa20 Bac_Lieu    ALL      0.133      0.021     0.185     0.108              -0.052                -0.087
#   viirs_snpp Bac_Lieu    ALL      0.075     -0.012     0.136     0.104              -0.061                -0.092
#  himawari_l2 Bac_Lieu    dry      0.165     -0.035     0.269     0.121              -0.104                -0.086
#  himawari_l3 Bac_Lieu    dry      0.172     -0.146     0.087     0.019               0.085                 0.127
# ...
