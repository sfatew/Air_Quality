# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import datetime

# Cấu hình giao diện đồ thị
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
path="/home/slow_data/Air_Quality/AOD/station_aod/all_station05.csv"

# %%
df = pd.read_csv(path)
df.head()
# Out:
#        timestamp  48806  48808  48820  48825  48826   48830  48840  48845  \
# 0  20220927_0000    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# 1  20220927_0030    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# 2  20220927_0020    NaN    NaN    NaN    NaN    NaN  2.1342    NaN    NaN
# 3  20220927_0040    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# 4  20220927_0050    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
#
#    48848  ...  48855  48866  48870  48877  48887  48900  48914  48917  VVDL0  \
# 0    NaN  ...    NaN    NaN    NaN    0.0    0.0    NaN    NaN    NaN    NaN
# 1    NaN  ...    NaN    NaN    NaN    0.0    0.0    NaN    NaN    NaN    NaN
# 2    NaN  ...    NaN    NaN    NaN    0.0    0.0    NaN    NaN    NaN    NaN
# 3    NaN  ...    NaN    NaN    NaN    0.0    0.0    NaN    NaN    NaN    NaN
# 4    NaN  ...    NaN    NaN    NaN    0.0    0.0    NaN    NaN    NaN    NaN
#
#    VVGL0
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# ...

# %%
df_HN = df['48820']
df_HN.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 164419 entries, 0 to 164418
# Series name: 48820
# Non-Null Count  Dtype
# --------------  -----
# 2680 non-null   float64
# dtypes: float64(1)
# memory usage: 1.3 MB
